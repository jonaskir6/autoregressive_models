# %%
import torch
import datasets, networks, sampling
import matplotlib.pyplot as plt
from torch import nn

# %%
#HYPERPARAMETERS
num_epochs = 25

# TODO Select a optimizer. [ 'adam', 'adamw', 'rmsprop' ]
optimizer_option = 'adam'

# TODO Select a lr scheduler. [ 'step', 'cosine', 'exponential']
lr_scheduler_option = ''

# TODO Select a batch size.
batch_size = 64

# TODO Select a learning rate.
lr = 1e-3


num_residual = 12
num_kernels = 64

# %%
ds = datasets.Dataset('cifar10', batch_size=batch_size)
training_data = ds.get_train_data_loader()
test_data = ds.get_test_data_loader()

# ds.visualize_dataset(training_data)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:05<00:00, 29768757.09it/s]
# Extracting data/cifar-10-python.tar.gz to data

# %%
# Training for cifar10
import time
from torch.optim.lr_scheduler import StepLR, ExponentialLR, CosineAnnealingLR
from torch.optim import Adam, AdamW, RMSprop, SGD

PixelCNN = networks.PixelCNN(num_kernels=num_kernels)
# Select device
# if torch.cuda.is_available():
#   device = torch.device('cuda:0')
# else:
#   device = torch.device('cpu')
device = torch.device('cuda:0')
print(f'Using device: {device}')
print('=========================================')

PixelCNN.to(device)

total_loss, total_loss_r, total_loss_g, total_loss_b = [], [], [], []
optimizer = None

# Select optimizer
if optimizer_option == "adam":
  optimizer = torch.optim.Adam(PixelCNN.parameters(), lr)

elif optimizer_option == "adamw":
  optimizer = torch.optim.AdamW(PixelCNN.parameters(), lr)

elif optimizer_option == "rmsprop":
  optimizer = torch.optim.RMSprop(PixelCNN.parameters(), lr)

else:
  optimizer = torch.optim.SGD(PixelCNN.parameters(), lr, momentum=0.9)


#Select scheduler
# scheduler = None
# if lr_scheduler_option == 'step':
#     scheduler = StepLR(optimizer, step_size=2, gamma=0.9)

# elif lr_scheduler_option == 'exponential':
#     scheduler = ExponentialLR(optimizer, gamma=0.9)

# elif lr_scheduler_option == 'cosine':
#     scheduler = CosineAnnealingLR(optimizer, T_max=50, eta_min=0.0001)

overall_start_time = time.time()

# training loop
for epoch in range(num_epochs):

  epoch_start_time = time.time()
  # Switch to training mode.
  PixelCNN.train()

  losses, losses_r, losses_g, losses_b = [], [], [], []
  batch_idx = 0

  for images, labels in training_data:

    images = images.to(device).to(torch.float32)

    target_r = (images[:, 0, :, :]*255).long().to(device)
    target_g = (images[:, 1, :, :]*255).long().to(device)
    target_b = (images[:, 2, :, :]*255).long().to(device)

    optimizer.zero_grad()

    r = PixelCNN(images, 'r')
    g = PixelCNN(images, 'g')
    b = PixelCNN(images, 'b')

    loss_r = nn.functional.cross_entropy(r, target_r)
    loss_g = nn.functional.cross_entropy(g, target_g)
    loss_b = nn.functional.cross_entropy(b, target_b)

    loss = loss_r + loss_g + loss_b

    losses_r.append(loss_r.detach().clone())
    losses_b.append(loss_g.detach().clone())
    losses_g.append(loss_b.detach().clone())
    losses.append(loss.detach().clone())

    loss.backward()
    optimizer.step()


    losses.append(loss.detach().clone())

    if batch_idx % 100 == 0:
      average_loss = torch.stack(losses).mean().item()
      print(f'Epoch: {epoch + 1:3d}/{num_epochs:3d}, Batch {batch_idx + 1:5d}, Loss: {average_loss:.4f}')
    batch_idx += 1

  # scheduler.step()
  epoch_end_time = time.time()
  print('-----------------------------------------')
  print(f'Epoch: {epoch + 1:3d} took {epoch_end_time - epoch_start_time:.2f}s')
  avg_loss_train_r = torch.stack(losses_r).mean().item()
  avg_loss_train_g = torch.stack(losses_g).mean().item()
  avg_loss_train_b = torch.stack(losses_b).mean().item()
  avg_loss_train = torch.stack(losses).mean().item()
  if epoch % 1 == 0:
    print(f"epoch: {epoch+1} -> Loss: {avg_loss_train:.3f} ---- Loss Red: {avg_loss_train_r:.3f} ---- Loss Green: {avg_loss_train_g:.3f} ---- Loss Blue: {avg_loss_train_b:.3f}")
    sampling.sampling(PixelCNN, device)
  print('-----------------------------------------')



overall_end_time = time.time()
print('=========================================')
print(f'Training took {overall_end_time - overall_start_time:.2f}s')
# Out:
# Using device: cuda:0
# =========================================
# Epoch:   1/ 25, Batch     1, Loss: 16.6448
# Epoch:   1/ 25, Batch   101, Loss: 14.5514
# Epoch:   1/ 25, Batch   201, Loss: 13.5812
# Epoch:   1/ 25, Batch   301, Loss: 13.0637
# Epoch:   1/ 25, Batch   401, Loss: 12.7561
# Epoch:   1/ 25, Batch   501, Loss: 12.5635
# Epoch:   1/ 25, Batch   601, Loss: 12.3966
# Epoch:   1/ 25, Batch   701, Loss: 12.2715
# -----------------------------------------
# Epoch:   1 took 228.71s
# epoch: 1 -> Loss: 12.182 ---- Loss Red: 4.070 ---- Loss Green: 4.052 ---- Loss Blue: 4.060
# -----------------------------------------
# Epoch:   2/ 25, Batch     1, Loss: 11.6987
# Epoch:   2/ 25, Batch   101, Loss: 11.3070
# Epoch:   2/ 25, Batch   201, Loss: 11.2732
# Epoch:   2/ 25, Batch   301, Loss: 11.2346
# Epoch:   2/ 25, Batch   401, Loss: 11.2213
# Epoch:   2/ 25, Batch   501, Loss: 11.1982
# Epoch:   2/ 25, Batch   601, Loss: 11.1621
# Epoch:   2/ 25, Batch   701, Loss: 11.1336
# -----------------------------------------
# Epoch:   2 took 228.85s
# epoch: 2 -> Loss: 11.114 ---- Loss Red: 3.709 ---- Loss Green: 3.703 ---- Loss Blue: 3.702
# -----------------------------------------
# Epoch:   3/ 25, Batch     1, Loss: 10.6994
# Epoch:   3/ 25, Batch   101, Loss: 10.9232
# Epoch:   3/ 25, Batch   201, Loss: 10.8912
# Epoch:   3/ 25, Batch   301, Loss: 10.8654
# Epoch:   3/ 25, Batch   401, Loss: 10.8410
# Epoch:   3/ 25, Batch   501, Loss: 10.8236
# Epoch:   3/ 25, Batch   601, Loss: 10.8044
# Epoch:   3/ 25, Batch   701, Loss: 10.7937
# -----------------------------------------
# Epoch:   3 took 228.14s
# epoch: 3 -> Loss: 10.784 ---- Loss Red: 3.600 ---- Loss Green: 3.594 ---- Loss Blue: 3.590
# -----------------------------------------
# Epoch:   4/ 25, Batch     1, Loss: 10.6300
# Epoch:   4/ 25, Batch   101, Loss: 10.6959
# Epoch:   4/ 25, Batch   201, Loss: 10.6681
# Epoch:   4/ 25, Batch   301, Loss: 10.6505
# Epoch:   4/ 25, Batch   401, Loss: 10.6472
# Epoch:   4/ 25, Batch   501, Loss: 10.6410
# Epoch:   4/ 25, Batch   601, Loss: 10.6348
# Epoch:   4/ 25, Batch   701, Loss: 10.6290
# -----------------------------------------
# Epoch:   4 took 227.96s
# epoch: 4 -> Loss: 10.622 ---- Loss Red: 3.547 ---- Loss Green: 3.540 ---- Loss Blue: 3.535
# -----------------------------------------
# Epoch:   5/ 25, Batch     1, Loss: 10.3227
# Epoch:   5/ 25, Batch   101, Loss: 10.5777
# Epoch:   5/ 25, Batch   201, Loss: 10.5690
# Epoch:   5/ 25, Batch   301, Loss: 10.5811
# Epoch:   5/ 25, Batch   401, Loss: 10.5644
# Epoch:   5/ 25, Batch   501, Loss: 10.5573
# Epoch:   5/ 25, Batch   601, Loss: 10.5497
# Epoch:   5/ 25, Batch   701, Loss: 10.5458
# -----------------------------------------
# Epoch:   5 took 227.25s
# epoch: 5 -> Loss: 10.541 ---- Loss Red: 3.519 ---- Loss Green: 3.514 ---- Loss Blue: 3.508
# -----------------------------------------
# Epoch:   6/ 25, Batch     1, Loss: 10.5097
# Epoch:   6/ 25, Batch   101, Loss: 10.4640
# Epoch:   6/ 25, Batch   201, Loss: 10.4704
# Epoch:   6/ 25, Batch   301, Loss: 10.4764
# Epoch:   6/ 25, Batch   401, Loss: 10.4849
# Epoch:   6/ 25, Batch   501, Loss: 10.4745
# Epoch:   6/ 25, Batch   601, Loss: 10.4728
# Epoch:   6/ 25, Batch   701, Loss: 10.4697
# -----------------------------------------
# Epoch:   6 took 227.18s
# epoch: 6 -> Loss: 10.468 ---- Loss Red: 3.496 ---- Loss Green: 3.490 ---- Loss Blue: 3.483
# -----------------------------------------
# Epoch:   7/ 25, Batch     1, Loss: 10.5408
# Epoch:   7/ 25, Batch   101, Loss: 10.5081
# Epoch:   7/ 25, Batch   201, Loss: 10.4870
# Epoch:   7/ 25, Batch   301, Loss: 10.4374
# Epoch:   7/ 25, Batch   401, Loss: 10.4342
# Epoch:   7/ 25, Batch   501, Loss: 10.4278
# Epoch:   7/ 25, Batch   601, Loss: 10.4190
# Epoch:   7/ 25, Batch   701, Loss: 10.4293
# -----------------------------------------
# Epoch:   7 took 227.14s
# epoch: 7 -> Loss: 10.423 ---- Loss Red: 3.480 ---- Loss Green: 3.477 ---- Loss Blue: 3.467
# -----------------------------------------
# Epoch:   8/ 25, Batch     1, Loss: 10.2004
# Epoch:   8/ 25, Batch   101, Loss: 10.3650
# Epoch:   8/ 25, Batch   201, Loss: 10.3529
# Epoch:   8/ 25, Batch   301, Loss: 10.3589
# Epoch:   8/ 25, Batch   401, Loss: 10.3738
# Epoch:   8/ 25, Batch   501, Loss: 10.3582
# Epoch:   8/ 25, Batch   601, Loss: 10.3658
# Epoch:   8/ 25, Batch   701, Loss: 10.3535
# -----------------------------------------
# Epoch:   8 took 227.10s
# epoch: 8 -> Loss: 10.356 ---- Loss Red: 3.459 ---- Loss Green: 3.453 ---- Loss Blue: 3.444
# -----------------------------------------
# Epoch:   9/ 25, Batch     1, Loss: 10.4855
# Epoch:   9/ 25, Batch   101, Loss: 10.3684
# Epoch:   9/ 25, Batch   201, Loss: 10.3396
# Epoch:   9/ 25, Batch   301, Loss: 10.3583
# Epoch:   9/ 25, Batch   401, Loss: 10.3408
# Epoch:   9/ 25, Batch   501, Loss: 10.3303
# Epoch:   9/ 25, Batch   601, Loss: 10.3241
# Epoch:   9/ 25, Batch   701, Loss: 10.3211
# -----------------------------------------
# Epoch:   9 took 227.05s
# epoch: 9 -> Loss: 10.317 ---- Loss Red: 3.446 ---- Loss Green: 3.441 ---- Loss Blue: 3.431
# -----------------------------------------
# Epoch:  10/ 25, Batch     1, Loss: 10.3057
# Epoch:  10/ 25, Batch   101, Loss: 10.2807
# Epoch:  10/ 25, Batch   201, Loss: 10.2817
# Epoch:  10/ 25, Batch   301, Loss: 10.2903
# Epoch:  10/ 25, Batch   401, Loss: 10.2734
# Epoch:  10/ 25, Batch   501, Loss: 10.2840
# Epoch:  10/ 25, Batch   601, Loss: 10.2863
# Epoch:  10/ 25, Batch   701, Loss: 10.2752
# -----------------------------------------
# Epoch:  10 took 226.53s
# epoch: 10 -> Loss: 10.277 ---- Loss Red: 3.433 ---- Loss Green: 3.427 ---- Loss Blue: 3.417
# -----------------------------------------
# Epoch:  11/ 25, Batch     1, Loss: 10.2118
# Epoch:  11/ 25, Batch   101, Loss: 10.2808
# Epoch:  11/ 25, Batch   201, Loss: 10.2668
# Epoch:  11/ 25, Batch   301, Loss: 10.2530
# Epoch:  11/ 25, Batch   401, Loss: 10.2432
# Epoch:  11/ 25, Batch   501, Loss: 10.2550
# Epoch:  11/ 25, Batch   601, Loss: 10.2552
# Epoch:  11/ 25, Batch   701, Loss: 10.2498
# -----------------------------------------
# Epoch:  11 took 226.86s
# epoch: 11 -> Loss: 10.245 ---- Loss Red: 3.423 ---- Loss Green: 3.417 ---- Loss Blue: 3.406
# -----------------------------------------
# Epoch:  12/ 25, Batch     1, Loss: 10.1226
# Epoch:  12/ 25, Batch   101, Loss: 10.2865
# Epoch:  12/ 25, Batch   201, Loss: 10.2412
# Epoch:  12/ 25, Batch   301, Loss: 10.2257
# Epoch:  12/ 25, Batch   401, Loss: 10.2321
# Epoch:  12/ 25, Batch   501, Loss: 10.2485
# Epoch:  12/ 25, Batch   601, Loss: 10.2417
# Epoch:  12/ 25, Batch   701, Loss: 10.2421
# -----------------------------------------
# Epoch:  12 took 226.12s
# epoch: 12 -> Loss: 10.240 ---- Loss Red: 3.420 ---- Loss Green: 3.416 ---- Loss Blue: 3.404
# -----------------------------------------
# Epoch:  13/ 25, Batch     1, Loss: 10.7208
# Epoch:  13/ 25, Batch   101, Loss: 10.2968
# Epoch:  13/ 25, Batch   201, Loss: 10.2253
# Epoch:  13/ 25, Batch   301, Loss: 10.2297
# Epoch:  13/ 25, Batch   401, Loss: 10.2182
# Epoch:  13/ 25, Batch   501, Loss: 10.2203
# Epoch:  13/ 25, Batch   601, Loss: 10.2077
# Epoch:  13/ 25, Batch   701, Loss: 10.2073
# -----------------------------------------
# Epoch:  13 took 226.47s
# epoch: 13 -> Loss: 10.203 ---- Loss Red: 3.408 ---- Loss Green: 3.404 ---- Loss Blue: 3.391
# -----------------------------------------
# Epoch:  14/ 25, Batch     1, Loss: 10.1579
# Epoch:  14/ 25, Batch   101, Loss: 10.2076
# Epoch:  14/ 25, Batch   201, Loss: 10.2014
# Epoch:  14/ 25, Batch   301, Loss: 10.2029
# Epoch:  14/ 25, Batch   401, Loss: 10.1915
# Epoch:  14/ 25, Batch   501, Loss: 10.1831
# Epoch:  14/ 25, Batch   601, Loss: 10.1918
# Epoch:  14/ 25, Batch   701, Loss: 10.1798
# -----------------------------------------
# Epoch:  14 took 226.14s
# epoch: 14 -> Loss: 10.177 ---- Loss Red: 3.400 ---- Loss Green: 3.395 ---- Loss Blue: 3.382
# -----------------------------------------
# Epoch:  15/ 25, Batch     1, Loss: 10.1303
# Epoch:  15/ 25, Batch   101, Loss: 10.1216
# Epoch:  15/ 25, Batch   201, Loss: 10.1189
# Epoch:  15/ 25, Batch   301, Loss: 10.1484
# Epoch:  15/ 25, Batch   401, Loss: 10.1407
# Epoch:  15/ 25, Batch   501, Loss: 10.1426
# Epoch:  15/ 25, Batch   601, Loss: 10.1404
# Epoch:  15/ 25, Batch   701, Loss: 10.1424
# -----------------------------------------
# Epoch:  15 took 226.03s
# epoch: 15 -> Loss: 10.141 ---- Loss Red: 3.389 ---- Loss Green: 3.382 ---- Loss Blue: 3.370
# -----------------------------------------
# Epoch:  16/ 25, Batch     1, Loss: 10.5434
# Epoch:  16/ 25, Batch   101, Loss: 10.1341
# Epoch:  16/ 25, Batch   201, Loss: 10.1198
# Epoch:  16/ 25, Batch   301, Loss: 10.1433
# Epoch:  16/ 25, Batch   401, Loss: 10.1493
# Epoch:  16/ 25, Batch   501, Loss: 10.1523
# Epoch:  16/ 25, Batch   601, Loss: 10.1403
# Epoch:  16/ 25, Batch   701, Loss: 10.1467
# -----------------------------------------
# Epoch:  16 took 226.10s
# epoch: 16 -> Loss: 10.145 ---- Loss Red: 3.390 ---- Loss Green: 3.384 ---- Loss Blue: 3.371
# -----------------------------------------
# Epoch:  17/ 25, Batch     1, Loss: 10.2124
# Epoch:  17/ 25, Batch   101, Loss: 10.0996
# Epoch:  17/ 25, Batch   201, Loss: 10.0861
# Epoch:  17/ 25, Batch   301, Loss: 10.0927
# Epoch:  17/ 25, Batch   401, Loss: 10.0812
# Epoch:  17/ 25, Batch   501, Loss: 10.0884
# Epoch:  17/ 25, Batch   601, Loss: 10.0926
# Epoch:  17/ 25, Batch   701, Loss: 10.0934
# -----------------------------------------
# Epoch:  17 took 226.04s
# epoch: 17 -> Loss: 10.106 ---- Loss Red: 3.378 ---- Loss Green: 3.370 ---- Loss Blue: 3.358
# -----------------------------------------
# Epoch:  18/ 25, Batch     1, Loss: 10.2773
# Epoch:  18/ 25, Batch   101, Loss: 10.0595
# Epoch:  18/ 25, Batch   201, Loss: 10.0834
# Epoch:  18/ 25, Batch   301, Loss: 10.0819
# Epoch:  18/ 25, Batch   401, Loss: 10.1047
# Epoch:  18/ 25, Batch   501, Loss: 10.1060
# Epoch:  18/ 25, Batch   601, Loss: 10.1009
# Epoch:  18/ 25, Batch   701, Loss: 10.1037
# -----------------------------------------
# Epoch:  18 took 225.77s
# epoch: 18 -> Loss: 10.104 ---- Loss Red: 3.376 ---- Loss Green: 3.371 ---- Loss Blue: 3.357
# -----------------------------------------
# Epoch:  19/ 25, Batch     1, Loss: 9.9225
# Epoch:  19/ 25, Batch   101, Loss: 10.0511
# Epoch:  19/ 25, Batch   201, Loss: 10.0820
# Epoch:  19/ 25, Batch   301, Loss: 10.0656
# Epoch:  19/ 25, Batch   401, Loss: 10.0768
# Epoch:  19/ 25, Batch   501, Loss: 10.0700
# Epoch:  19/ 25, Batch   601, Loss: 10.0824
# Epoch:  19/ 25, Batch   701, Loss: 10.0871
# -----------------------------------------
# Epoch:  19 took 225.89s
# epoch: 19 -> Loss: 10.091 ---- Loss Red: 3.372 ---- Loss Green: 3.366 ---- Loss Blue: 3.352
# -----------------------------------------
# Epoch:  20/ 25, Batch     1, Loss: 9.8802
# Epoch:  20/ 25, Batch   101, Loss: 10.0455
# Epoch:  20/ 25, Batch   201, Loss: 10.0836
# Epoch:  20/ 25, Batch   301, Loss: 10.0707
# Epoch:  20/ 25, Batch   401, Loss: 10.0632
# Epoch:  20/ 25, Batch   501, Loss: 10.0632
# Epoch:  20/ 25, Batch   601, Loss: 10.0608
# Epoch:  20/ 25, Batch   701, Loss: 10.0612
# -----------------------------------------
# Epoch:  20 took 226.00s
# epoch: 20 -> Loss: 10.062 ---- Loss Red: 3.363 ---- Loss Green: 3.356 ---- Loss Blue: 3.342
# -----------------------------------------
# Epoch:  21/ 25, Batch     1, Loss: 10.0908
# Epoch:  21/ 25, Batch   101, Loss: 10.0954
# Epoch:  21/ 25, Batch   201, Loss: 10.0915
# Epoch:  21/ 25, Batch   301, Loss: 10.0774
# Epoch:  21/ 25, Batch   401, Loss: 10.0685
# Epoch:  21/ 25, Batch   501, Loss: 10.0726
# Epoch:  21/ 25, Batch   601, Loss: 10.0656
# Epoch:  21/ 25, Batch   701, Loss: 10.0626
# -----------------------------------------
# Epoch:  21 took 225.71s
# epoch: 21 -> Loss: 10.057 ---- Loss Red: 3.361 ---- Loss Green: 3.356 ---- Loss Blue: 3.341
# -----------------------------------------
# Epoch:  22/ 25, Batch     1, Loss: 9.8359
# Epoch:  22/ 25, Batch   101, Loss: 10.0254
# Epoch:  22/ 25, Batch   201, Loss: 10.0225
# Epoch:  22/ 25, Batch   301, Loss: 10.0091
# Epoch:  22/ 25, Batch   401, Loss: 10.0293
# Epoch:  22/ 25, Batch   501, Loss: 10.0256
# Epoch:  22/ 25, Batch   601, Loss: 10.0284
# Epoch:  22/ 25, Batch   701, Loss: 10.0358
# -----------------------------------------
# Epoch:  22 took 225.51s
# epoch: 22 -> Loss: 10.037 ---- Loss Red: 3.355 ---- Loss Green: 3.349 ---- Loss Blue: 3.334
# -----------------------------------------
# Epoch:  23/ 25, Batch     1, Loss: 10.0209
# Epoch:  23/ 25, Batch   101, Loss: 9.9790
# Epoch:  23/ 25, Batch   201, Loss: 10.0072
# Epoch:  23/ 25, Batch   301, Loss: 10.0140
# Epoch:  23/ 25, Batch   401, Loss: 10.0124
# Epoch:  23/ 25, Batch   501, Loss: 10.0120
# Epoch:  23/ 25, Batch   601, Loss: 10.0146
# Epoch:  23/ 25, Batch   701, Loss: 10.0190
# -----------------------------------------
# Epoch:  23 took 225.49s
# epoch: 23 -> Loss: 10.021 ---- Loss Red: 3.349 ---- Loss Green: 3.343 ---- Loss Blue: 3.328
# -----------------------------------------
# Epoch:  24/ 25, Batch     1, Loss: 10.0845
# Epoch:  24/ 25, Batch   101, Loss: 10.0448
# Epoch:  24/ 25, Batch   201, Loss: 10.0110
# Epoch:  24/ 25, Batch   301, Loss: 10.0115
# Epoch:  24/ 25, Batch   401, Loss: 10.0209
# Epoch:  24/ 25, Batch   501, Loss: 10.0172
# Epoch:  24/ 25, Batch   601, Loss: 10.0121
# Epoch:  24/ 25, Batch   701, Loss: 10.0107
# -----------------------------------------
# Epoch:  24 took 225.42s
# epoch: 24 -> Loss: 10.009 ---- Loss Red: 3.345 ---- Loss Green: 3.339 ---- Loss Blue: 3.324
# -----------------------------------------
# Epoch:  25/ 25, Batch     1, Loss: 9.8871
# Epoch:  25/ 25, Batch   101, Loss: 9.9947
# Epoch:  25/ 25, Batch   201, Loss: 10.0011
# Epoch:  25/ 25, Batch   301, Loss: 9.9975
# Epoch:  25/ 25, Batch   401, Loss: 10.0044
# Epoch:  25/ 25, Batch   501, Loss: 10.0093
# Epoch:  25/ 25, Batch   601, Loss: 10.0082
# Epoch:  25/ 25, Batch   701, Loss: 10.0005
# -----------------------------------------
# Epoch:  25 took 225.66s
# epoch: 25 -> Loss: 9.999 ---- Loss Red: 3.343 ---- Loss Green: 3.336 ---- Loss Blue: 3.321
# -----------------------------------------
# =========================================
# Training took 6012.03s
